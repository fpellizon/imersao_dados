# %% [markdown]
# <a href="https://colab.research.google.com/github/fpellizon/imersao_dados/blob/master/imersao_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## AULA 01

# %%
#importa bibliotecas 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# define URL da base de dados 
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

# efetua a leitura da base de dados considerando a compressão do tipo zip
dados = pd.read_csv(url_dados,compression = 'zip')

#imprime o conteúdo da base de dados
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
#imprime as 5 primeiras linhas
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# retorna número de linhas e colunas da base de dados
dados.shape
# Out:
# (23814, 877)

# %%
# plota apenas a série (coluna) tratamento
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
# retorna os valores únicos da série tratamento
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
# retorna os valores únicos da série tempo
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
# retorna os valores únicos da série dose
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
# retorna os valores únicos da série droga
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
# retorna os valores únicos da série g-0
dados['g0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
#contagem de valores unicos da série tratamento (frequencia)
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['dose'].value_counts(normalize=True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
# grafico de torta para serie tratamento
dados['tratamento'].value_counts().plot.pie()

# %%
# grafico de torta para serie tempo
dados['tempo'].value_counts().plot.pie()

# %%
# grafico de barras para serie tempo
dados['tempo'].value_counts().plot.bar()

# %%
# apresenta apenas o dataframe filtrado com a condicao atendida
dados_filtrados = dados[dados['g0'] > 0]
dados_filtrados.head()
dados_filtrados.shape
# Out:
# (11769, 877)

# %%
dados_ftrat1 = dados.query("tratamento=='com_controle'")
dados_ftrat2 = dados.query("tratamento=='com_droga'")

# %%
dados_ftrat1['tempo'].value_counts(normalize=True)
# Out:
# 48    0.347267
# 72    0.327974
# 24    0.324759
# Name: tempo, dtype: float64

# %%
dados_ftrat1['dose'].value_counts(normalize=True)
# Out:
# D1    0.509646
# D2    0.490354
# Name: dose, dtype: float64

# %%
dados_ftrat1['droga'].unique().shape
# Out:
# (1,)

# %%
dados_ftrat2['tempo'].value_counts(normalize=True)
# Out:
# 48    0.346364
# 72    0.327137
# 24    0.326499
# Name: tempo, dtype: float64

# %%
dados_ftrat2['dose'].value_counts(normalize=True)
# Out:
# D1    0.510115
# D2    0.489885
# Name: dose, dtype: float64

# %%
dados_ftrat2['droga'].value_counts().shape
# Out:
# (3288,)

# %% [markdown]
# ### DESAFIOS AULA 01
#
# #### Desafio 01: Investigar por que a classe tratamento é tão desbalanceada
#
# #### Desafio 02: Plotar as 5 últimas linhas da tabela
#   dados.tail()
#
# #### Desafio 03: Proporção das classes tratamento
#   dados['tratamento'].value_counts(normalize=True)
#
# #### Desafio 04: Quantas tipos de drogas foram investigados ?
#   dados['droga'].value_counts().shape -> 3289
#
# #### Desafio 05: Procurar na documentação o método query.
#
# dados.query('g0 > 0')
#
# #### Desafio 06: Renomear as colunas do dataframe removendo o hifen
#
# #### Desafio 07: Incluir titulo e legenda nos graficos
#
# #### Desafio 08: Resumo do que aprendeu com os dados

# %%
#desafio 01
print(f"Total de dados {len(dados['id'])}\n")
print(f"Quantidade de drogas {len(dados.groupby(['droga', 'tratamento']).count()['id'])}\n")
display(dados.query('tratamento == "com_controle"').value_counts('droga'))
print()
display(dados.query('droga == "cacb2b860"').value_counts('tratamento'))
print()
# Out:
# Total de dados 23814
#
# Quantidade de drogas 3289
# droga
# cacb2b860    1866
# dtype: int64
# tratamento
# com_controle    1866
# dtype: int64

# %%
# desafio 02
dados.tail()
#dados[-5:]
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
# desafio 03
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
#desafio 04
dados['droga'].value_counts().shape[0]
#len(dados['droga'].unique())
# Out:
# 3289

# %%
#desafio 05
dados.query('g0 > 0')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
#desafio 06
nome_das_colunas = dados.columns
novo_nome_coluna = []
for coluna in nome_das_colunas:
  coluna = coluna.replace('-', '')
  novo_nome_coluna.append(coluna)
dados.columns = novo_nome_coluna 

mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#desafio 07

import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
valore_tempo = dados['tempo'].value_counts(ascending=True)
ax = valore_tempo.sort_index().plot.bar()
ax.set_title('Amostras por tempo', fontsize=20)
ax.set_xlabel('Tempo', fontsize=18)
ax.set_ylabel('Amostras', fontsize=18)
plt.xticks(rotation = 0, fontsize=16)
plt.yticks(fontsize=16)
plt.show()

#dados['tempo'].value_counts().plot.bar(legend=True, xlabel="Horas", ylabel="Amostras", title='Distribuição de Amostras x Tempo', fontsize=10)

# %% [markdown]
# ## AULA 02

# %%
#separa os top 5 compostos em uma lista com índice (chave) e contagem

compostos = dados['composto'].value_counts()[0:5]

compostos
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
# Name: composto, dtype: int64

# %%
compostos.index.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')>

# %%
#extrai somente os índices em formato de lista

cod_compostos = dados['composto'].value_counts().index[0:5]

cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
#filtra o dataframe contendo apenas os top 5 indices 
# o @ aponta para uma variavel declarada em outro bloco / celula

dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
# Import seaborn
import seaborn as sns

sns.countplot(x = 'composto', data=dados)

# %%
# Import seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# Aplica tema padrão
sns.set_theme()
plt.figure(figsize=(10,8))

dadosgrf = dados.query('composto in @cod_compostos')

fntdic = {'fontsize': 20,
 'fontweight' : 'regular', \
 'color' : 'black', \
 'verticalalignment': 'bottom', \
 'horizontalalignment': 'center'}

ax = sns.countplot(x = 'composto', data=dadosgrf, order= cod_compostos.to_list() )
ax.set_title("Top 5 Compostos", fntdic)
plt.show()

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %%
dados['g0'].hist(bins=100)

# %%
dados['g19'].hist(bins=100)

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g0','g1']]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:,'g0':'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:,'g0':'g771'].describe().transpose()
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]

# %%
dados.loc[:,'g0':'g771'].describe().transpose()['mean'].hist(bins=50)

# %%
dados.loc[:,'g0':'g771'].describe().transpose()['min'].hist(bins=50)

# %%
dados.loc[:,'g0':'g771'].describe().transpose()['max'].hist(bins=50)

# %%
dados.loc[:,'c0':'c99'].describe().transpose()['mean'].hist(bins=50)

# %%
sns.boxplot(x= 'g0' , data=dados)

# %%
plt.figure(figsize=(10,30))

sns.boxplot(y= 'g0',x='tratamento' , data=dados)

# %% [markdown]
# ### DESAFIOS AULA 02
#
# #### Desafio 01: Ordenar o gráfico count plot
#
# #### Desafio 02: Melhorar a visualização aumentando o tamanho da fonte
#
# #### Desafio 03: Plotar os histogramas com seaborn
#
# #### Desafio 04: Estudar sobre as estatísticas retornadas no .describe()

# %% [markdown]
# # AULA 03

# %%
pd.crosstab(dados['dose'],dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g0','g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g0',y='g3', data=dados )

# %%
sns.scatterplot(x='g0',y='g8', data=dados )

# %%
sns.lmplot(x='g0',y='g8', data=dados, line_kws={'color':'red'})

# %%
sns.lmplot(x='g0',y='g8', data=dados, line_kws={'color':'red'},col='tratamento',row='tempo')

# %%
dados.loc[:,'g0':'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
# Compute the correlation matrix
corr = dados.loc[:,'g0':'g50'].corr()

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()


# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [markdown]
# ### DESAFIOS AULA 03
#
# #### Desafio 01: Criar tabelas de frequencia com o pandas.groupby
#
# #### Desafio 02: Normalizar o crosstab pela coluna
#
# #### Desafio 03: Explorar outros agregadores
#
# #### Desafio 04: Explorar o melt

# %%
#desafio 01
dados.groupby(['dose','tempo','tratamento']).count()['g0']
# Out:
# dose  tempo  tratamento
# D1    24     com_controle     301
#              com_droga       3585
#       48     com_controle     343
#              com_droga       4011
#       72     com_controle     307
#              com_droga       3600
# D2    24     com_controle     305
#              com_droga       3581
#       48     com_controle     305
#              com_droga       3591
#       72     com_controle     305
#              com_droga       3580
# Name: g0, dtype: int64

# %%
#desafio 02

pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize='columns')
